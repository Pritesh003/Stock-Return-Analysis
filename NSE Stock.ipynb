# %% [markdown]
# ### Importing necessary libraries

# %%
from nsepy import get_history
from datetime import date
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# ### Getting data of two of the biggest Pharma companies from nsepy.

# %%
SunPharma = get_history(symbol='SUNPHARMA', start=date(2019,3,1), end=date(2020,2,29))
Lupin = get_history(symbol='LUPIN', start=date(2019,3,1), end=date(2020,2,29))

# %% [markdown]
# ### Saving the data in .csv file for future use.

# %%
SunPharma.to_csv('SunPharma.csv')
Lupin.to_csv('Lupin.csv')

# %% [markdown]
# #### Taking a look at the data sets

# %%
SunPharma
# Out:
#                Symbol Series  Prev Close    Open    High     Low    Last  \
# Date
# 2019-03-01  SUNPHARMA     EQ      445.15  447.90  451.00  445.05  447.10
# 2019-03-05  SUNPHARMA     EQ      447.35  447.85  456.90  445.35  455.70
# 2019-03-06  SUNPHARMA     EQ      455.90  457.00  469.35  446.95  455.80
# 2019-03-07  SUNPHARMA     EQ      460.55  459.50  463.00  448.80  450.65
# 2019-03-08  SUNPHARMA     EQ      450.90  449.50  457.90  447.30  454.90
# ...               ...    ...         ...     ...     ...     ...     ...
# 2020-02-24  SUNPHARMA     EQ      404.95  406.50  414.65  395.80  397.30
# 2020-02-25  SUNPHARMA     EQ      397.85  402.40  402.40  385.30  387.50
# 2020-02-26  SUNPHARMA     EQ      388.90  385.10  386.95  372.50  374.00
# 2020-02-27  SUNPHARMA     EQ      374.70  375.00  390.70  369.45  388.00
# 2020-02-28  SUNPHARMA     EQ      388.50  379.65  385.60  371.10  373.20
#
#              Close    VWAP    Volume      Turnover  Trades  \
# Date
# ...

# %%
Lupin
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2019-03-01  LUPIN     EQ      763.75  771.20  790.55  768.45  790.55  786.60
# 2019-03-05  LUPIN     EQ      786.60  791.55  791.60  778.10  785.20  784.60
# 2019-03-06  LUPIN     EQ      784.60  786.00  794.60  781.05  787.50  789.05
# 2019-03-07  LUPIN     EQ      789.05  788.00  803.50  785.30  792.00  792.00
# 2019-03-08  LUPIN     EQ      792.00  797.90  799.80  775.35  776.00  779.15
# ...           ...    ...         ...     ...     ...     ...     ...     ...
# 2020-02-24  LUPIN     EQ      699.60  695.00  697.00  669.00  672.75  672.85
# 2020-02-25  LUPIN     EQ      672.85  680.00  680.00  667.40  671.00  669.15
# 2020-02-26  LUPIN     EQ      669.15  668.10  676.00  664.55  667.85  669.80
# 2020-02-27  LUPIN     EQ      669.80  669.10  671.30  654.60  664.00  662.80
# 2020-02-28  LUPIN     EQ      662.80  656.15  659.40  635.20  640.45  640.00
#
# ...

# %% [markdown]
# ### Calculating return for both the data sets using the closing price of stock.

# %%
SunPharma['Return'] = SunPharma['Close'] - SunPharma['Prev Close']
SunPharma['%Return'] = SunPharma['Close'].pct_change()
SunPharma.head()
# Out:
#                Symbol Series  Prev Close    Open    High     Low    Last  \
# Date
# 2019-03-01  SUNPHARMA     EQ      445.15  447.90  451.00  445.05  447.10
# 2019-03-05  SUNPHARMA     EQ      447.35  447.85  456.90  445.35  455.70
# 2019-03-06  SUNPHARMA     EQ      455.90  457.00  469.35  446.95  455.80
# 2019-03-07  SUNPHARMA     EQ      460.55  459.50  463.00  448.80  450.65
# 2019-03-08  SUNPHARMA     EQ      450.90  449.50  457.90  447.30  454.90
#
#              Close    VWAP    Volume      Turnover  Trades  \
# Date
# 2019-03-01  447.35  448.42   5608805  2.515108e+14   62891
# 2019-03-05  455.90  452.62   5251255  2.376804e+14  113346
# 2019-03-06  460.55  459.49  13004184  5.975283e+14  162356
# 2019-03-07  450.90  455.16  10701581  4.870887e+14  114160
# 2019-03-08  454.95  454.58   5040326  2.291244e+14   78653
#
#             Deliverable Volume  %Deliverble  Return   %Return
# Date
# 2019-03-01             1916646       0.3417    2.20       NaN
# ...

# %%
Lupin['Return'] = Lupin['Close'] - Lupin['Prev Close']
Lupin['%Return'] = Lupin['Close'].pct_change()
Lupin.head()
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2019-03-01  LUPIN     EQ      763.75  771.20  790.55  768.45  790.55  786.60
# 2019-03-05  LUPIN     EQ      786.60  791.55  791.60  778.10  785.20  784.60
# 2019-03-06  LUPIN     EQ      784.60  786.00  794.60  781.05  787.50  789.05
# 2019-03-07  LUPIN     EQ      789.05  788.00  803.50  785.30  792.00  792.00
# 2019-03-08  LUPIN     EQ      792.00  797.90  799.80  775.35  776.00  779.15
#
#               VWAP   Volume      Turnover  Trades  Deliverable Volume  \
# Date
# 2019-03-01  777.59  2349879  1.827253e+14   35836             1154049
# 2019-03-05  784.37  1220769  9.575303e+13   32625              312043
# 2019-03-06  788.10  1395812  1.100041e+14   34828              441158
# 2019-03-07  796.68  1852651  1.475972e+14   42480              577371
# 2019-03-08  790.53  1971916  1.558863e+14   42651              472530
#
#             %Deliverble  Return   %Return
# Date
# ...

# %% [markdown]
# ### Plotting the stock price and return for both the stocks.

# %%
f, axes = plt.subplots(2,1, figsize=(18,8))
axes[0].plot(SunPharma['Close'], color='orange', marker='o', markersize=3, linewidth=1)
axes[1].plot(Lupin['Close'], color='blue', marker='o', markersize=3, linewidth=1)
axes[0].legend(['Sun Pharma'])
axes[1].legend(['Lupin'])
plt.suptitle('Closing Price', size=24)
plt.show()

# %%
f, axes = plt.subplots(2,1, figsize=(18,8))
axes[0].plot(SunPharma['Return'], color='orange', marker='o', markersize=3, linewidth=1)
axes[1].plot(Lupin['Return'], c='blue', marker='o', markersize=3, linewidth=1)
axes[0].legend(['Sun Pharma'])
axes[1].legend(['Lupin'])
plt.suptitle('Return', size=24)
plt.show()

# %%
f, axes = plt.subplots(1,2, figsize=(18,6))
axes[0].hist(SunPharma['Return'], color='orange')
axes[1].hist(Lupin['Return'], color='blue')
axes[0].legend(['Sun Pharma'])
axes[1].legend(['Lupin'])
plt.suptitle('Return', size=24)
plt.show()

# %% [markdown]
# ### Question: Why stock return distribution is not a Normal curve?
# The stock return plot above looks normal but if we look to the left of the distribution, we can see fat tails. The fat tails mean that extreme events occur more frequently in reality than what a normal distribution would predict. The actual distribution of the returns is skinnier in its center than the normal distribution. The skinny middle and the fat tails imply that the normal distribution might not be the best describer of stock returns.

# %% [markdown]
# #### Mean

# %%
SP_mean = SunPharma['Return'].mean()
LP_mean = Lupin['Return'].mean()

print('Mean return for Sun Pharma is {:.4f} for Mar-2019 to Feb-2020'.format(SP_mean))
print('Mean return for Lupin is {:.4f} for Mar-2019 to Feb-2020'.format(LP_mean))
# Out:
# Mean return for Sun Pharma is -0.2949 for Mar-2019 to Feb-2020
# Mean return for Lupin is -0.5051 for Mar-2019 to Feb-2020

# %% [markdown]
# #### Variance

# %%
SP_var =  SunPharma['Return'].var()
LP_var = Lupin['Return'].var()

print('Variance for Sun Pharma is {:.4f} for Mar-2019 to Feb-2020'.format(SP_var))
print('Variance for Lupin is {:.4f} for Mar-2019 to Feb-2020'.format(LP_var))
# Out:
# Variance for Sun Pharma is 62.6463 for Mar-2019 to Feb-2020
# Variance for Lupin is 146.9416 for Mar-2019 to Feb-2020

# %% [markdown]
# ### Question: Why we use variance as a risk measure?
# Variance measures variability from the average or mean. To investors, variability is volatility, and volatility is a measure of risk. Variance is of paramount importance as they are used to measure security and market volatility, which in turn plays a large role in creating a profitable trading strategy.

# %% [markdown]
# #### Skewness

# %%
SP_skew =  SunPharma['Return'].skew()
LP_skew = Lupin['Return'].skew()

print('Skewness for Sun Pharma is {:.4f} for Mar-2019 to Feb-2020'.format(SP_skew))
print('Skewness for Lupin is {:.4f} for Mar-2019 to Feb-2020'.format(LP_skew))
# Out:
# Skewness for Sun Pharma is -0.2115 for Mar-2019 to Feb-2020
# Skewness for Lupin is -0.1283 for Mar-2019 to Feb-2020

# %% [markdown]
# #### Kurtosis

# %%
SP_kurt =  SunPharma['Return'].kurtosis()
LP_kurt = Lupin['Return'].kurtosis()

print('Kurtosis for Sun Pharma is {:.4f} for Mar-2019 to Feb-2020'.format(SP_kurt))
print('Kurtosis for Lupin is {:.4f} for Mar-2019 to Feb-2020'.format(LP_kurt))
# Out:
# Kurtosis for Sun Pharma is 2.5039 for Mar-2019 to Feb-2020
# Kurtosis for Lupin is 0.9630 for Mar-2019 to Feb-2020

# %% [markdown]
# ### Correlation between the stocks.

# %%
data = {'SP_Close': SunPharma['Close'], 'Lup_Close': Lupin['Close']}
data = pd.DataFrame(data)
data
# Out:
#             SP_Close  Lup_Close
# Date
# 2019-03-01    447.35     786.60
# 2019-03-05    455.90     784.60
# 2019-03-06    460.55     789.05
# 2019-03-07    450.90     792.00
# 2019-03-08    454.95     779.15
# ...              ...        ...
# 2020-02-24    397.85     672.85
# 2020-02-25    388.90     669.15
# 2020-02-26    374.70     669.80
# 2020-02-27    388.50     662.80
# 2020-02-28    372.90     640.00
#
# [245 rows x 2 columns]

# %%
data.corr()
# Out:
#            SP_Close  Lup_Close
# SP_Close   1.000000   0.611159
# Lup_Close  0.611159   1.000000

# %%
plt.figure(figsize=(10,6))
sns.regplot('SP_Close', 'Lup_Close', data = data, marker = '+')
plt.title('Regression Plot', size=18)
plt.show()

# %% [markdown]
# ### Question: Causation vs Correlation.
# Correlation is a statistical measure (expressed as a number) that describes the size and direction of a relationship between two or more variables. A correlation between variables, however, does not automatically mean that the change in one variable is the cause of the change in the values of the other variable.
#
# Causation indicates that one event is the result of the occurrence of the other event; i.e. there is a causal relationship between the two events. This is also referred to as cause and effect.
#
# #### Correlation doesn't imply causation.
# We can see that there is a positive correlation between both the stocks. Both stocks decrease and increase somewhat togather, but it doesn't imply that decrease in return of any one stock will cause the return of other stock to drop. There could be a third factor that influence the stock price for both the stocks in a similar way so that it appears to decrease or increase together.

# %% [markdown]
# ### Importing Nifty Pharma data.

# %%
NiftyPharma = get_history(symbol='NIFTY PHARMA', start=date(2019,3,1), end=date(2020,2,29), index=True)
NiftyPharma
# Out:
#                Open     High      Low    Close      Volume      Turnover
# Date
# 2019-03-01  8909.00  8993.80  8882.20  8972.65  16221791.0  1.206720e+10
# 2019-03-05  8975.20  9066.40  8937.90  9054.65  16054127.0  1.159330e+10
# 2019-03-06  9088.45  9193.05  9026.60  9155.00  23513017.0  1.692730e+10
# 2019-03-07  9129.65  9209.15  9021.50  9045.65  24337312.0  1.727900e+10
# 2019-03-08  9038.85  9085.20  9007.80  9021.85  15832832.0  1.204680e+10
# ...             ...      ...      ...      ...         ...           ...
# 2020-02-24  8275.95  8281.95  8086.65  8115.55  50488414.0  2.542040e+10
# 2020-02-25  8153.85  8153.85  7898.35  7938.45  39869569.0  2.155970e+10
# 2020-02-26  7886.35  7931.70  7813.95  7839.20  44448864.0  2.377210e+10
# 2020-02-27  7824.50  7903.55  7740.95  7885.15  40519410.0  2.155450e+10
# 2020-02-28  7751.45  7786.60  7559.00  7576.75  35181304.0  2.231680e+10
#
# [245 rows x 6 columns]

# %% [markdown]
# ### Saving the data as a .csv file for future use.

# %%
NiftyPharma.to_csv('NiftyPharma.csv')

# %%
data['NiftyP_Close'] = NiftyPharma['Close']
data.head()
# Out:
#             SP_Close  Lup_Close  NiftyP_Close
# Date
# 2019-03-01    447.35     786.60       8972.65
# 2019-03-05    455.90     784.60       9054.65
# 2019-03-06    460.55     789.05       9155.00
# 2019-03-07    450.90     792.00       9045.65
# 2019-03-08    454.95     779.15       9021.85

# %% [markdown]
# ### Plotting the data along with NIFTY PHARMA.

# %%
f, axes = plt.subplots(3,1, figsize=(18,8))
axes[0].plot(data['NiftyP_Close'], c='orange', marker='o', markersize=3, linewidth=1)
axes[1].plot(data['SP_Close'], color='b', marker='o', markersize=3, linewidth=1)
axes[2].plot(data['Lup_Close'], c='c', marker='o', markersize=3, linewidth=1)
axes[0].legend(['Nifty Pharma'], loc = 'best')
axes[1].legend(['Sun Pharma'], loc = 'best')
axes[2].legend(['Lupin'], loc = 'best')
plt.suptitle('Comparision wrt NIFTY PHARMA', size=24)
plt.show()

# %%
sns.pairplot(data)
plt.show()

# %% [markdown]
# We can clearly see the fat tails in the above plot.
